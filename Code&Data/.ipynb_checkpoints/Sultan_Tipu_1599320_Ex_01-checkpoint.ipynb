# %%
# Import data
import pandas as pd
df = pd.read_csv("AAPL01.csv")
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1990-01-02  0.314732  0.334821  0.312500  0.332589   0.265325  183198400
# 1  1990-01-03  0.339286  0.339286  0.334821  0.334821   0.267106  207995200
# 2  1990-01-04  0.341518  0.345982  0.332589  0.335938   0.267997  221513600
# 3  1990-01-05  0.337054  0.341518  0.330357  0.337054   0.268887  123312000
# 4  1990-01-08  0.334821  0.339286  0.330357  0.339286   0.270668  101572800

# %%
# Taking only the closing price and date coumn
df = df[['Date', 'Close']]
df.head()
# Out:
#          Date     Close
# 0  1990-01-02  0.332589
# 1  1990-01-03  0.334821
# 2  1990-01-04  0.335938
# 3  1990-01-05  0.337054
# 4  1990-01-08  0.339286

# %%
# Formetting date and index
import datetime

def datetime_str(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)
datetime_object = datetime_str('1990-01-02')

df['Date'] = df['Date'].apply(datetime_str)
df['Date']
df.index = df.pop('Date')
df.head()
# Out:
#                Close
# Date
# 1990-01-02  0.332589
# 1990-01-03  0.334821
# 1990-01-04  0.335938
# 1990-01-05  0.337054
# 1990-01-08  0.339286

# %%
# See how the data data looks like
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
# This function will give us output on the based of the input. 
# Target 1, Target 2, Target 3 are the previous value respectively to the current date.
# Target is the predicted outut. 

import numpy as np

def windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = datetime_str(first_date_str)
  last_date  = datetime_str(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = windowed_df(df, 
                                '1990-01-05', 
                                '2022-07-29', 
                                n=3)
windowed_df
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     1990-01-05    0.332589    0.334821    0.335938    0.337054
# 1     1990-01-08    0.334821    0.335938    0.337054    0.339286
# 2     1990-01-09    0.335938    0.337054    0.339286    0.335938
# 3     1990-01-10    0.337054    0.339286    0.335938    0.321429
# 4     1990-01-11    0.339286    0.335938    0.321429    0.308036
# ...          ...         ...         ...         ...         ...
# 8200  2022-07-25  153.039993  155.350006  154.089996  152.949997
# 8201  2022-07-26  155.350006  154.089996  152.949997  151.600006
# 8202  2022-07-27  154.089996  152.949997  151.600006  156.789993
# 8203  2022-07-28  152.949997  151.600006  156.789993  157.350006
# 8204  2022-07-29  151.600006  156.789993  157.350006  162.509995
#
# [8205 rows x 5 columns]

# %%
# Here this function will separate the data to train and validate the model
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
D80 = int(len(dates) * .8) # 80% data to train the model
D90 = int(len(dates) * .9) # The next 10% data to validate the model

dates_train, X_train, y_train = dates[:D80], X[:D80], y[:D80]

dates_val, X_val, y_val = dates[D80:D90], X[D80:D90], y[D80:D90]
dates_test, X_test, y_test = dates[D90:], X[D90:], y[D90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
# Building our model by using the 'tensorflow' package.
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 206/206 [==============================] - 4s 8ms/step - loss: 24.8224 - mean_absolute_error: 1.7050 - val_loss: 80.5861 - val_mean_absolute_error: 6.5196
# Epoch 2/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0454 - mean_absolute_error: 0.0970 - val_loss: 63.4219 - val_mean_absolute_error: 5.6155
# Epoch 3/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0527 - mean_absolute_error: 0.1027 - val_loss: 59.6900 - val_mean_absolute_error: 5.3607
# Epoch 4/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0415 - mean_absolute_error: 0.0934 - val_loss: 56.7811 - val_mean_absolute_error: 5.2206
# Epoch 5/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0399 - mean_absolute_error: 0.0916 - val_loss: 55.2770 - val_mean_absolute_error: 5.1051
# Epoch 6/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0489 - mean_absolute_error: 0.1052 - val_loss: 54.9398 - val_mean_absolute_error: 5.0815
# Epoch 7/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0421 - mean_absolute_error: 0.0953 - val_loss: 56.4100 - val_mean_absolute_error: 5.2822
# Epoch 8/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0385 - mean_absolute_error: 0.0916 - val_loss: 49.9191 - val_mean_absolute_error: 4.8348
# Epoch 9/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0421 - mean_absolute_error: 0.0955 - val_loss: 55.8986 - val_mean_absolute_error: 5.4261
# Epoch 10/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0471 - mean_absolute_error: 0.1018 - val_loss: 53.6563 - val_mean_absolute_error: 5.0049
# Epoch 11/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0407 - mean_absolute_error: 0.0947 - val_loss: 57.7149 - val_mean_absolute_error: 5.3733
# Epoch 12/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0444 - mean_absolute_error: 0.0976 - val_loss: 54.7589 - val_mean_absolute_error: 5.1129
# Epoch 13/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0397 - mean_absolute_error: 0.0926 - val_loss: 50.9027 - val_mean_absolute_error: 4.8377
# Epoch 14/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0500 - mean_absolute_error: 0.1060 - val_loss: 51.9745 - val_mean_absolute_error: 4.9498
# Epoch 15/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0412 - mean_absolute_error: 0.0942 - val_loss: 53.2976 - val_mean_absolute_error: 5.0259
# Epoch 16/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0443 - mean_absolute_error: 0.0982 - val_loss: 55.9139 - val_mean_absolute_error: 5.1347
# Epoch 17/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0390 - mean_absolute_error: 0.0919 - val_loss: 50.8624 - val_mean_absolute_error: 4.8203
# Epoch 18/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0484 - mean_absolute_error: 0.1021 - val_loss: 51.7313 - val_mean_absolute_error: 4.8798
# Epoch 19/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0432 - mean_absolute_error: 0.0985 - val_loss: 46.3343 - val_mean_absolute_error: 4.5304
# Epoch 20/100
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0383 - mean_absolute_error: 0.0928 - val_loss: 49.8923 - val_mean_absolute_error: 4.7849
# Epoch 21/100
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0443 - mean_absolute_error: 0.1006 - val_loss: 49.7641 - val_mean_absolute_error: 4.7938
# Epoch 22/100
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0391 - mean_absolute_error: 0.0906 - val_loss: 47.8686 - val_mean_absolute_error: 4.6992
# Epoch 23/100
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0400 - mean_absolute_error: 0.0956 - val_loss: 45.8121 - val_mean_absolute_error: 4.6021
# Epoch 24/100
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0370 - mean_absolute_error: 0.0891 - val_loss: 44.6347 - val_mean_absolute_error: 4.4393
# Epoch 25/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0411 - mean_absolute_error: 0.0951 - val_loss: 42.4739 - val_mean_absolute_error: 4.3370
# Epoch 26/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0375 - mean_absolute_error: 0.0912 - val_loss: 43.1656 - val_mean_absolute_error: 4.3630
# Epoch 27/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0389 - mean_absolute_error: 0.0914 - val_loss: 41.5495 - val_mean_absolute_error: 4.2376
# Epoch 28/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0411 - mean_absolute_error: 0.0951 - val_loss: 40.7818 - val_mean_absolute_error: 4.1878
# Epoch 29/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0416 - mean_absolute_error: 0.0954 - val_loss: 49.3695 - val_mean_absolute_error: 4.8112
# Epoch 30/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0364 - mean_absolute_error: 0.0902 - val_loss: 42.3835 - val_mean_absolute_error: 4.3725
# Epoch 31/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0356 - mean_absolute_error: 0.0911 - val_loss: 43.8036 - val_mean_absolute_error: 4.6120
# Epoch 32/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0397 - mean_absolute_error: 0.0933 - val_loss: 41.7661 - val_mean_absolute_error: 4.2952
# Epoch 33/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0458 - mean_absolute_error: 0.1031 - val_loss: 39.8352 - val_mean_absolute_error: 4.1789
# Epoch 34/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0406 - mean_absolute_error: 0.0934 - val_loss: 40.2911 - val_mean_absolute_error: 4.2273
# Epoch 35/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0378 - mean_absolute_error: 0.0917 - val_loss: 41.4695 - val_mean_absolute_error: 4.3344
# Epoch 36/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0380 - mean_absolute_error: 0.0898 - val_loss: 33.9506 - val_mean_absolute_error: 3.8116
# Epoch 37/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0488 - mean_absolute_error: 0.1016 - val_loss: 35.1831 - val_mean_absolute_error: 3.8798
# Epoch 38/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0441 - mean_absolute_error: 0.1010 - val_loss: 36.1145 - val_mean_absolute_error: 3.9416
# Epoch 39/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0408 - mean_absolute_error: 0.0941 - val_loss: 34.1669 - val_mean_absolute_error: 3.7846
# Epoch 40/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0383 - mean_absolute_error: 0.0912 - val_loss: 37.1057 - val_mean_absolute_error: 4.0713
# Epoch 41/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0425 - mean_absolute_error: 0.0975 - val_loss: 33.3642 - val_mean_absolute_error: 3.7555
# Epoch 42/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0440 - mean_absolute_error: 0.0984 - val_loss: 34.6183 - val_mean_absolute_error: 3.8734
# Epoch 43/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0481 - mean_absolute_error: 0.1040 - val_loss: 41.4777 - val_mean_absolute_error: 4.3101
# Epoch 44/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0339 - mean_absolute_error: 0.0850 - val_loss: 33.6995 - val_mean_absolute_error: 3.7771
# Epoch 45/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0411 - mean_absolute_error: 0.0946 - val_loss: 30.6065 - val_mean_absolute_error: 3.5553
# Epoch 46/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0435 - mean_absolute_error: 0.0975 - val_loss: 41.1705 - val_mean_absolute_error: 4.3100
# Epoch 47/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0437 - mean_absolute_error: 0.1027 - val_loss: 33.1916 - val_mean_absolute_error: 3.7605
# Epoch 48/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0379 - mean_absolute_error: 0.0918 - val_loss: 32.9823 - val_mean_absolute_error: 3.7625
# Epoch 49/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0408 - mean_absolute_error: 0.0959 - val_loss: 36.0396 - val_mean_absolute_error: 4.1252
# Epoch 50/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0386 - mean_absolute_error: 0.0892 - val_loss: 36.9107 - val_mean_absolute_error: 4.2049
# Epoch 51/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0471 - mean_absolute_error: 0.1048 - val_loss: 45.8600 - val_mean_absolute_error: 4.9518
# Epoch 52/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0419 - mean_absolute_error: 0.0944 - val_loss: 36.8706 - val_mean_absolute_error: 4.2760
# Epoch 53/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0423 - mean_absolute_error: 0.0976 - val_loss: 32.8591 - val_mean_absolute_error: 3.7338
# Epoch 54/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0410 - mean_absolute_error: 0.0945 - val_loss: 42.5956 - val_mean_absolute_error: 4.6401
# Epoch 55/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0432 - mean_absolute_error: 0.0956 - val_loss: 30.6222 - val_mean_absolute_error: 3.5714
# Epoch 56/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0355 - mean_absolute_error: 0.0886 - val_loss: 33.8511 - val_mean_absolute_error: 3.8158
# Epoch 57/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0404 - mean_absolute_error: 0.0928 - val_loss: 30.1322 - val_mean_absolute_error: 3.5743
# Epoch 58/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0382 - mean_absolute_error: 0.0893 - val_loss: 41.4769 - val_mean_absolute_error: 4.5509
# Epoch 59/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0424 - mean_absolute_error: 0.0967 - val_loss: 33.4417 - val_mean_absolute_error: 3.7835
# Epoch 60/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0349 - mean_absolute_error: 0.0852 - val_loss: 36.0534 - val_mean_absolute_error: 4.1766
# Epoch 61/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0389 - mean_absolute_error: 0.0912 - val_loss: 32.1062 - val_mean_absolute_error: 3.7208
# Epoch 62/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0355 - mean_absolute_error: 0.0871 - val_loss: 28.8110 - val_mean_absolute_error: 3.4481
# Epoch 63/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0380 - mean_absolute_error: 0.0933 - val_loss: 25.9735 - val_mean_absolute_error: 3.2698
# Epoch 64/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0423 - mean_absolute_error: 0.0959 - val_loss: 32.5194 - val_mean_absolute_error: 3.8188
# Epoch 65/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0413 - mean_absolute_error: 0.0960 - val_loss: 32.5906 - val_mean_absolute_error: 3.8610
# Epoch 66/100
# 206/206 [==============================] - 1s 4ms/step - loss: 0.0417 - mean_absolute_error: 0.0953 - val_loss: 31.5551 - val_mean_absolute_error: 3.7735
# Epoch 67/100
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0406 - mean_absolute_error: 0.0953 - val_loss: 28.4516 - val_mean_absolute_error: 3.4477
# Epoch 68/100
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0355 - mean_absolute_error: 0.0877 - val_loss: 32.3757 - val_mean_absolute_error: 3.8686
# Epoch 69/100
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0351 - mean_absolute_error: 0.0864 - val_loss: 26.3059 - val_mean_absolute_error: 3.2646
# Epoch 70/100
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0461 - mean_absolute_error: 0.0997 - val_loss: 28.4405 - val_mean_absolute_error: 3.4402
# Epoch 71/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0374 - mean_absolute_error: 0.0906 - val_loss: 28.0670 - val_mean_absolute_error: 3.4720
# Epoch 72/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0335 - mean_absolute_error: 0.0833 - val_loss: 25.4931 - val_mean_absolute_error: 3.1805
# Epoch 73/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0445 - mean_absolute_error: 0.0944 - val_loss: 53.1151 - val_mean_absolute_error: 5.6590
# Epoch 74/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0490 - mean_absolute_error: 0.1040 - val_loss: 34.3771 - val_mean_absolute_error: 3.8755
# Epoch 75/100
# 206/206 [==============================] - 1s 4ms/step - loss: 0.0338 - mean_absolute_error: 0.0831 - val_loss: 26.7782 - val_mean_absolute_error: 3.3101
# Epoch 76/100
# 206/206 [==============================] - 2s 7ms/step - loss: 0.0377 - mean_absolute_error: 0.0891 - val_loss: 26.0007 - val_mean_absolute_error: 3.2561
# Epoch 77/100
# 206/206 [==============================] - 1s 7ms/step - loss: 0.0377 - mean_absolute_error: 0.0895 - val_loss: 28.0698 - val_mean_absolute_error: 3.3930
# Epoch 78/100
# 206/206 [==============================] - 1s 4ms/step - loss: 0.0379 - mean_absolute_error: 0.0894 - val_loss: 30.3966 - val_mean_absolute_error: 3.7322
# Epoch 79/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0443 - mean_absolute_error: 0.1007 - val_loss: 29.0737 - val_mean_absolute_error: 3.4659
# Epoch 80/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0333 - mean_absolute_error: 0.0866 - val_loss: 31.8048 - val_mean_absolute_error: 3.7119
# Epoch 81/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0352 - mean_absolute_error: 0.0886 - val_loss: 25.1660 - val_mean_absolute_error: 3.1750
# Epoch 82/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0355 - mean_absolute_error: 0.0883 - val_loss: 35.0105 - val_mean_absolute_error: 4.0413
# Epoch 83/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0348 - mean_absolute_error: 0.0857 - val_loss: 28.4868 - val_mean_absolute_error: 3.4368
# Epoch 84/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0377 - mean_absolute_error: 0.0933 - val_loss: 26.4510 - val_mean_absolute_error: 3.2542
# Epoch 85/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0359 - mean_absolute_error: 0.0870 - val_loss: 26.6405 - val_mean_absolute_error: 3.3320
# Epoch 86/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0506 - mean_absolute_error: 0.1053 - val_loss: 33.9680 - val_mean_absolute_error: 3.9364
# Epoch 87/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0380 - mean_absolute_error: 0.0899 - val_loss: 28.6465 - val_mean_absolute_error: 3.4787
# Epoch 88/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0400 - mean_absolute_error: 0.0931 - val_loss: 26.4865 - val_mean_absolute_error: 3.2462
# Epoch 89/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0402 - mean_absolute_error: 0.0941 - val_loss: 33.1446 - val_mean_absolute_error: 3.8651
# Epoch 90/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0436 - mean_absolute_error: 0.0971 - val_loss: 32.3293 - val_mean_absolute_error: 3.7411
# Epoch 91/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0486 - mean_absolute_error: 0.1058 - val_loss: 31.3984 - val_mean_absolute_error: 3.6957
# Epoch 92/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0359 - mean_absolute_error: 0.0885 - val_loss: 30.5243 - val_mean_absolute_error: 3.6308
# Epoch 93/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0366 - mean_absolute_error: 0.0887 - val_loss: 29.6803 - val_mean_absolute_error: 3.5310
# Epoch 94/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0438 - mean_absolute_error: 0.0960 - val_loss: 31.2290 - val_mean_absolute_error: 3.7159
# Epoch 95/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0349 - mean_absolute_error: 0.0853 - val_loss: 27.3419 - val_mean_absolute_error: 3.3603
# Epoch 96/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0415 - mean_absolute_error: 0.0926 - val_loss: 31.1818 - val_mean_absolute_error: 3.6844
# Epoch 97/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0347 - mean_absolute_error: 0.0856 - val_loss: 25.5127 - val_mean_absolute_error: 3.2110
# Epoch 98/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0371 - mean_absolute_error: 0.0891 - val_loss: 26.1719 - val_mean_absolute_error: 3.2502
# Epoch 99/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0351 - mean_absolute_error: 0.0862 - val_loss: 30.1961 - val_mean_absolute_error: 3.6000
# Epoch 100/100
# 206/206 [==============================] - 1s 3ms/step - loss: 0.0340 - mean_absolute_error: 0.0863 - val_loss: 25.3217 - val_mean_absolute_error: 3.1696

# %%
# Train the model. 
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 206/206 [==============================] - 0s 1ms/step

# %%
# Validate the model
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.title("Figure 01: Validation Predictions vs Validation Observations")
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 26/26 [==============================] - 0s 2ms/step

# %%
# forcast and compare
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.title("Figure 02: Forecast Predictions vs Forecast Observations")
plt.legend(['Forecast Predictions', 'Forecast Observations'])
# Out:
# 26/26 [==============================] - 0s 1ms/step
